# %%
# !pip install bs4
# !pip install requests
# !pip install html5lib
# !pip install folium
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.4.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=a5cb421907562f240bcb4ed462f3c4c3bfefd481890aae1db2f90763985a8283
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib) (0.5.1)

# %%
import requests
import folium

# %%
api_key = '{api_key}'
#add IP to end of URL

# %%
f = open('/content/IPAdressesTXT.txt').read()
results = []
for ip in f.splitlines():
  url = "https://api.apilayer.com/ip_to_location/" + ip
  payload = {}
  headers= {
  "apikey": api_key
  }
  response = requests.request("GET", url, headers=headers, data = payload)
  results.append(response.text)
print(results)
# Out:
# ['{\n    "ip": "172.98.73.11",\n    "type": "ipv4",\n    "latitude": 43.700111,\n    "longitude": -79.416298,\n    "is_eu": false,\n    "continent_code": "NA",\n    "continent_name": "North America",\n    "country_code": "CA",\n    "country_name": "Canada",\n    "region_name": "Ontario",\n    "city": "Toronto",\n    "location": {\n        "capital": "Ottawa",\n        "native_name": "Canada",\n        "flag": "http://assets.promptapi.com/flags/CA.svg",\n        "top_level_domains": [\n            ".ca"\n        ],\n        "calling_codes": [\n            "1"\n        ]\n    },\n    "connection": {\n        "asn": 46562,\n        "isp": "Total Server Solutions L.L.C."\n    },\n    "currencies": [\n        {\n            "name": "Canadian dollar",\n            "code": "CAD",\n            "symbol": "$"\n        }\n    ],\n    "timezones": [\n        "UTC-08:00",\n        "UTC-07:00",\n        "UTC-06:00",\n        "UTC-05:00",\n        "UTC-04:00",\n        "UTC-03:30"\n    ]\n}\n', '{\n    "ip": "73.219.180.131",\n    "type": "ipv4",\n    "latitude": 41.562321,\n    "longitude": -72.65065,\n    "is_eu": false,\n    "continent_code": "NA",\n    "continent_name": "North America",\n    "country_code": "US",\n    "country_name": "United States of America",\n    "region_name": "Connecticut",\n    "city": "Middletown",\n    "location": {\n        "capital": "Washington, D.C.",\n        "native_name": "United States",\n        "flag": "http://assets.promptapi.com/flags/US.svg",\n        "top_level_domains": [\n            ".us"\n        ],\n        "calling_codes": [\n            "1"\n        ]\n    },\n    "connection": {\n        "asn": 7015,\n        "isp": "Comcast Cable Communications, LLC"\n    },\n    "currencies": [\n        {\n            "name": "United States dollar",\n            "code": "USD",\n            "symbol": "$"\n        }\n    ],\n    "timezones": [\n        "UTC-12:00",\n        "UTC-11:00",\n        "UTC-10:00",\n        "UTC-09:00",\n        "UTC-08:00",\n        "UTC-07:00",\n        "UTC-06:00",\n        "UTC-05:00",\n        "UTC-04:00",\n        "UTC+10:00",\n        "UTC+12:00"\n    ]\n}\n', '{\n    "ip": "62.210.207.5",\n    "type": "ipv4",\n    "latitude": 48.853409,\n    "longitude": 2.3488,\n    "is_eu": true,\n    "continent_code": "EU",\n    "continent_name": "Europe",\n    "country_code": "FR",\n    "country_name": "France",\n    "region_name": "Ile-de-France",\n    "city": "Paris",\n    "location": {\n        "capital": "Paris",\n        "native_name": "France",\n        "flag": "http://assets.promptapi.com/flags/FR.svg",\n        "top_level_domains": [\n            ".fr"\n        ],\n        "calling_codes": [\n            "33"\n        ]\n    },\n    "connection": {\n        "asn": 12876,\n        "isp": "ONLINE S.A.S."\n    },\n    "currencies": [\n        {\n            "name": "Euro",\n            "code": "EUR",\n            "symbol": "\\u20ac"\n        }\n    ],\n    "timezones": [\n        "UTC-10:00",\n        "UTC-09:30",\n        "UTC-09:00",\n        "UTC-08:00",\n        "UTC-04:00",\n        "UTC-03:00",\n        "UTC+01:00",\n        "UTC+03:00",\n        "UTC+04:00",\n        "UTC+05:00",\n        "UTC+11:00",\n        "UTC+12:00"\n    ]\n}\n', '{\n    "ip": "173.255.228.176",\n    "type": "ipv4",\n    "latitude": 40.735661,\n    "longitude": -74.172371,\n    "is_eu": false,\n    "continent_code": "NA",\n    "continent_name": "North America",\n    "country_code": "US",\n    "country_name": "United States of America",\n    "region_name": "New Jersey",\n    "city": "Newark",\n    "location": {\n        "capital": "Washington, D.C.",\n        "native_name": "United States",\n        "flag": "http://assets.promptapi.com/flags/US.svg",\n        "top_level_domains": [\n            ".us"\n        ],\n        "calling_codes": [\n            "1"\n        ]\n    },\n    "connection": {\n        "asn": 63949,\n        "isp": "Linode, LLC"\n    },\n    "currencies": [\n        {\n            "na ...

# %%
def getNums(s):
  result = ''
  for c in s:
     if c.isnumeric() or c == '.' or c == '-':
      result += c
  return float(result)

pointList = []
#(Lat, Long)
for w in results:
  pointList.append((getNums(w.splitlines()[3]), getNums(w.splitlines()[4])))

# %%
print(pointList)
# Out:
# [(43.700111, -79.416298), (41.562321, -72.65065), (48.853409, 2.3488), (40.735661, -74.172371), (39.952339, -75.163788), (53.788441, -114.050652), (39.745949, -75.546593), (38.895111, -77.036369), (33.952599, -84.549927), (45.523449, -122.676208), (41.562321, -72.65065), (35.851257, -97.935966), (39.952339, -75.163788), (45.443283, -73.740852), (45.523449, -122.676208), (58.592709, -3.52594), (39.952339, -75.163788), (39.952339, -75.163788), (52.076672, 4.29861), (39.952339, -75.163788), (36.74773, -119.772369), (39.952339, -75.163788), (39.952339, -75.163788), (38.895111, -77.036369), (45.523449, -122.676208), (39.952339, -75.163788), (45.523449, -122.676208), (50.90395, -1.40428), (39.04372, -77.487488), (39.952339, -75.163788), (39.948891, -74.900276), (39.952339, -75.163788), (40.668522, 16.60158), (47.682899, -122.120903), (47.380932, -122.23484), (53.341839, -2.635), (42.3559, -71.052696), (39.952339, -75.163788), (52.374031, 4.88969), (40.44062, -79.995888), (40.608429, -75.490181), (45.523449, -122.676208), (48.853409, 2.3488), (50.38913, 30.370501), (41.4645, -81.508728), (